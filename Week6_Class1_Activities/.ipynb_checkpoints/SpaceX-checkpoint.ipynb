# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.spacexdata.com/v3/cores"

# %%
# Pretty print JSON for all launchpads
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Pretty print JSON for a specific launchpad
print(requests.get(url).json())
# Out:
# [{'core_serial': 'Merlin1A', 'block': None, 'status': 'lost', 'original_launch': '2006-03-24T22:30:00.000Z', 'original_launch_unix': 1143239400, 'missions': [{'name': 'FalconSat', 'flight': 1}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Engine failure at T+33 seconds resulted in loss of vehicle'}, {'core_serial': 'Merlin2A', 'block': None, 'status': 'lost', 'original_launch': '2007-03-21T01:10:00.000Z', 'original_launch_unix': 1174439400, 'missions': [{'name': 'DemoSat', 'flight': 2}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Successful first-stage burn and transition to second stage, maximal altitude 289 km. Harmonic oscillation at T+5 minutes Premature engine shutdown at T+7 min 30 s. Failed to reach orbit.'}, {'core_serial': 'Merlin1C', 'block': None, 'status': 'lost', 'original_launch': '2008-08-02T03:34:00.000Z', 'original_launch_unix': 1217648040, 'missions': [{'name': 'Trailblazer', 'flight': 3}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Residual stage-1 thrust led to collision between stage 1 and stage 2.'}, {'core_serial': 'Merlin2C', 'block': None, 'status': 'lost', 'original_launch': '2008-09-28T23:15:00.000Z', 'original_launch_unix': 1222643700, 'missions': [{'name': 'RatSat', 'flight': 4}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Initially scheduled for 23–25 Sep, carried dummy payload – mass simulator, 165 kg (originally intended to be RazakSAT.'}, {'core_serial': 'Merlin3C', 'block': None, 'status': 'lost', 'original_launch': '2009-07-13T03:35:00.000Z', 'original_launch_unix': 1247456100, 'missions': [{'name': 'RazakSat', 'flight': 5}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': None}, {'core_serial': 'B0003', 'block': 1, 'status': 'lost', 'original_launch': '2010-06-04T18:45:00.000Z', 'original_launch_unix': 1275677100, 'missions': [{'name': 'Falcon 9 Test Flight', 'flight': 6}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Stage Expended'}, {'core_serial': 'B0004', 'block': 1, 'status': 'lost', 'original_launch': '2010-12-08T15:43:00.000Z', 'original_launch_unix': 1291822980, 'missions': [{'name': 'COTS 1', 'flight': 7}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'First flight of Dragon'}, {'core_serial': 'B0005', 'block': 1, 'status': 'lost', 'original_launch': '2012-05-22T07:44:00.000Z', 'original_launch_unix': 1337672640, 'missions': [{'name': 'COTS 2', 'flight': 8}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': None}, {'core_serial': 'B0006', 'block': 1, 'status': 'lost', 'original_launch': '2012-10-08T00:35:00.000Z', 'original_launch_unix': 1349656500, 'missions': [{'name': 'CRS-1', 'flight': 9}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': 'Suffered engine out at T+1:19 but primary mission successful'}, {'core_serial': 'B0007', 'block': 1, 'status': 'lost', 'original_launch': '2013-03-01T19:10:00.000Z', 'original_launch_unix': 1362165000, 'missions': [{'name': 'CRS-2', 'flight': 10}], 'reuse_count': 0, 'rtls_attempts': 0, 'rtls_landings': 0, 'asds_attempts': 0, 'asds_landings': 0, 'water_landing': False, 'details': None}, {'core_serial': 'B1003', 'block': 1, 'status': 'lost', 'original_launch': '2013-09-29T16:00:00.000Z', 'original_launch_unix': 1380470400, 'missions': [{'name': 'CASSIOPE', 'flight':  ...

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": null,
#         "core_serial": "Merlin1A",
#         "details": "Engine failure at T+33 seconds resulted in loss of vehicle",
#         "missions": [
#             {
#                 "flight": 1,
#                 "name": "FalconSat"
#             }
#         ],
#         "original_launch": "2006-03-24T22:30:00.000Z",
#         "original_launch_unix": 1143239400,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": null,
#         "core_serial": "Merlin2A",
#         "details": "Successful first-stage burn and transition to second stage, maximal altitude 289 km. Harmonic oscillation at T+5 minutes Premature engine shutdown at T+7 min 30 s. Failed to reach orbit.",
#         "missions": [
#             {
#                 "flight": 2,
#                 "name": "DemoSat"
#             }
#         ],
#         "original_launch": "2007-03-21T01:10:00.000Z",
#         "original_launch_unix": 1174439400,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": null,
#         "core_serial": "Merlin1C",
#         "details": "Residual stage-1 thrust led to collision between stage 1 and stage 2.",
#         "missions": [
#             {
#                 "flight": 3,
#                 "name": "Trailblazer"
#             }
#         ],
#         "original_launch": "2008-08-02T03:34:00.000Z",
#         "original_launch_unix": 1217648040,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": null,
#         "core_serial": "Merlin2C",
#         "details": "Initially scheduled for 23\u201325 Sep, carried dummy payload \u2013 mass simulator, 165 kg (originally intended to be RazakSAT.",
#         "missions": [
#             {
#                 "flight": 4,
#                 "name": "RatSat"
#             }
#         ],
#         "original_launch": "2008-09-28T23:15:00.000Z",
#         "original_launch_unix": 1222643700,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": null,
#         "core_serial": "Merlin3C",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 5,
#                 "name": "RazakSat"
#             }
#         ],
#         "original_launch": "2009-07-13T03:35:00.000Z",
#         "original_launch_unix": 1247456100,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B0003",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 6,
#                 "name": "Falcon 9 Test Flight"
#             }
#         ],
#         "original_launch": "2010-06-04T18:45:00.000Z",
#         "original_launch_unix": 1275677100,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B0004",
#         "details": "First flight of Dragon",
#         "missions": [
#             {
#                 "flight": 7,
#                 "name": "COTS 1"
#             }
#         ],
#         "original_launch": "2010-12-08T15:43:00.000Z",
#         "original_launch_unix": 1291822980,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B0005",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 8,
#                 "name": "COTS 2"
#             }
#         ],
#         "original_launch": "2012-05-22T07:44:00.000Z",
#         "original_launch_unix": 1337672640,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B0006",
#         "details": "Suffered engine out at T+1:19 but primary mission successful",
#         "missions": [
#             {
#                 "flight": 9,
#                 "name": "CRS-1"
#             }
#         ],
#         "original_launch": "2012-10-08T00:35:00.000Z",
#         "original_launch_unix": 1349656500,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B0007",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 10,
#                 "name": "CRS-2"
#             }
#         ],
#         "original_launch": "2013-03-01T19:10:00.000Z",
#         "original_launch_unix": 1362165000,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1003",
#         "details": "First flight of Falcon 9 v1.1 upgrade, first Spacex flight from Vandenberg",
#         "missions": [
#             {
#                 "flight": 11,
#                 "name": "CASSIOPE"
#             }
#         ],
#         "original_launch": "2013-09-29T16:00:00.000Z",
#         "original_launch_unix": 1380470400,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1004",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 12,
#                 "name": "SES-8"
#             }
#         ],
#         "original_launch": "2013-12-03T22:41:00.000Z",
#         "original_launch_unix": 1386110460,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1005",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 13,
#                 "name": "Thaicom 6"
#             }
#         ],
#         "original_launch": "2014-01-06T18:06:00.000Z",
#         "original_launch_unix": 1389031560,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1006",
#         "details": "Broke up after sucessful water landing",
#         "missions": [
#             {
#                 "flight": 14,
#                 "name": "CRS-3"
#             }
#         ],
#         "original_launch": "2014-04-18T19:25:00.000Z",
#         "original_launch_unix": 1397849100,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1007",
#         "details": "Broke up after sucessful water landing",
#         "missions": [
#             {
#                 "flight": 15,
#                 "name": "OG-2 Mission 1"
#             }
#         ],
#         "original_launch": "2014-07-14T15:15:00.000Z",
#         "original_launch_unix": 1405350900,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1008",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 16,
#                 "name": "AsiaSat 8"
#             }
#         ],
#         "original_launch": "2014-08-05T08:00:00.000Z",
#         "original_launch_unix": 1407225600,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1011",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 17,
#                 "name": "AsiaSat 6"
#             }
#         ],
#         "original_launch": "2014-09-07T05:00:00.000Z",
#         "original_launch_unix": 1410066000,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1010",
#         "details": "Broke up after sucessful water landing",
#         "missions": [
#             {
#                 "flight": 18,
#                 "name": "CRS-4"
#             }
#         ],
#         "original_launch": "2014-09-21T05:52:00.000Z",
#         "original_launch_unix": 1411278720,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1012",
#         "details": "Destroyed on impact with droneship, grid fin hydraulic fluid depleted",
#         "missions": [
#             {
#                 "flight": 19,
#                 "name": "CRS-5"
#             }
#         ],
#         "original_launch": "2015-01-10T09:47:00.000Z",
#         "original_launch_unix": 1420883220,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1013",
#         "details": "Broke up after sucessful water landing",
#         "missions": [
#             {
#                 "flight": 20,
#                 "name": "DSCOVR"
#             }
#         ],
#         "original_launch": "2015-02-11T23:03:00.000Z",
#         "original_launch_unix": 1423695780,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1014",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 21,
#                 "name": "ABS-3A / Eutelsat 115W B"
#             }
#         ],
#         "original_launch": "2015-03-02T03:50:00.000Z",
#         "original_launch_unix": 1425268200,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1015",
#         "details": "Destroyed on impact with droneship due to excess lateral velocity - throttle stiction",
#         "missions": [
#             {
#                 "flight": 22,
#                 "name": "CRS-6"
#             }
#         ],
#         "original_launch": "2015-04-14T20:10:00.000Z",
#         "original_launch_unix": 1429042200,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1016",
#         "details": null,
#         "missions": [
#             {
#                 "flight": 23,
#                 "name": "T\u00fcrkmen\u00c4lem 52\u00b0E / MonacoSAT"
#             }
#         ],
#         "original_launch": "2015-04-27T23:03:00.000Z",
#         "original_launch_unix": 1430175780,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1018",
#         "details": "RUD at T + 139s - second stage overpressure event due to defective COPV strut heim joint",
#         "missions": [
#             {
#                 "flight": 24,
#                 "name": "CRS-7"
#             }
#         ],
#         "original_launch": "2015-06-28T14:21:00.000Z",
#         "original_launch_unix": 1435501260,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1019",
#         "details": "Retired; permanently displayed at Hawthorne headquarters. ",
#         "missions": [
#             {
#                 "flight": 25,
#                 "name": "OG-2 Mission 2"
#             }
#         ],
#         "original_launch": "2015-12-22T01:29:00.000Z",
#         "original_launch_unix": 1450747740,
#         "reuse_count": 0,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1017",
#         "details": "Destroyed after drone ship landing due to landing leg failure",
#         "missions": [
#             {
#                 "flight": 26,
#                 "name": "Jason 3"
#             }
#         ],
#         "original_launch": "2016-01-17T15:42:00.000Z",
#         "original_launch_unix": 1453045320,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 1,
#         "core_serial": "B1020",
#         "details": "Destroyed on Impact with DroneShip (OCISLY) - Excess Velocity, Possible Fuel Exhaustion",
#         "missions": [
#             {
#                 "flight": 27,
#                 "name": "SES-9"
#             }
#         ],
#         "original_launch": "2016-03-04T23:35:00.000Z",
#         "original_launch_unix": 1457134500,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 2,
#         "asds_landings": 2,
#         "block": 2,
#         "core_serial": "B1021",
#         "details": "Core will be given as a gift to the Cape.  ",
#         "missions": [
#             {
#                 "flight": 28,
#                 "name": "CRS-8"
#             },
#             {
#                 "flight": 38,
#                 "name": "SES-10"
#             }
#         ],
#         "original_launch": "2016-04-08T20:43:00.000Z",
#         "original_launch_unix": 1460148180,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 2,
#         "core_serial": "B1022",
#         "details": "Removed from active fleet for \u0394 Qualification Testing. Retired after eight to ten test cycles.  Currently partially disassembled at McGregor.",
#         "missions": [
#             {
#                 "flight": 29,
#                 "name": "JCSAT-2B"
#             }
#         ],
#         "original_launch": "2016-05-06T05:21:00.000Z",
#         "original_launch_unix": 1462512060,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 2,
#         "core_serial": "B1023",
#         "details": "*At LZ1 as 2018/02/06 ",
#         "missions": [
#             {
#                 "flight": 30,
#                 "name": "Thaicom 8"
#             },
#             {
#                 "flight": 55,
#                 "name": "Falcon Heavy Test Flight"
#             }
#         ],
#         "original_launch": "2016-05-27T21:39:00.000Z",
#         "original_launch_unix": 1464385140,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 2,
#         "core_serial": "B1024",
#         "details": "RUD on deck of droneship (OCISLY)",
#         "missions": [
#             {
#                 "flight": 31,
#                 "name": "ABS-2A / Eutelsat 117W B"
#             }
#         ],
#         "original_launch": "2016-06-15T14:29:00.000Z",
#         "original_launch_unix": 1466000940,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 2,
#         "core_serial": "B1025",
#         "details": "*At LZ2 as 2018/02/06 ",
#         "missions": [
#             {
#                 "flight": 32,
#                 "name": "CRS-9"
#             },
#             {
#                 "flight": 55,
#                 "name": "Falcon Heavy Test Flight"
#             }
#         ],
#         "original_launch": "2016-07-18T04:45:00.000Z",
#         "original_launch_unix": 1468817100,
#         "reuse_count": 1,
#         "rtls_attempts": 2,
#         "rtls_landings": 2,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 2,
#         "core_serial": "B1026",
#         "details": "Permanently scrapped.  ",
#         "missions": [
#             {
#                 "flight": 33,
#                 "name": "JCSAT-16"
#             }
#         ],
#         "original_launch": "2016-08-14T05:26:00.000Z",
#         "original_launch_unix": 1471152360,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1028",
#         "details": "Destroyed on pad September 1 2016 during static fire anomaly.",
#         "missions": [
#             {
#                 "flight": 34,
#                 "name": "Amos-6"
#             }
#         ],
#         "original_launch": "2016-09-01T13:07:00.000Z",
#         "original_launch_unix": 1472735220,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 2,
#         "asds_landings": 2,
#         "block": 3,
#         "core_serial": "B1029",
#         "details": "Will be given to KSC Visitors Center. ",
#         "missions": [
#             {
#                 "flight": 35,
#                 "name": "Iridium NEXT Mission 1"
#             },
#             {
#                 "flight": 42,
#                 "name": "BulgariaSat-1"
#             }
#         ],
#         "original_launch": "2017-01-14T17:54:00.000Z",
#         "original_launch_unix": 1484416440,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 3,
#         "core_serial": "B1031",
#         "details": "Stored outside at McGregor, partially disassembled (missing engines). ",
#         "missions": [
#             {
#                 "flight": 36,
#                 "name": "CRS-10"
#             },
#             {
#                 "flight": 49,
#                 "name": "SES-11 / Echostar 105"
#             }
#         ],
#         "original_launch": "2017-02-19T14:39:00.000Z",
#         "original_launch_unix": 1487515140,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1030",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 37,
#                 "name": "EchoStar 23"
#             }
#         ],
#         "original_launch": "2017-03-16T06:00:00.000Z",
#         "original_launch_unix": 1489644000,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1032",
#         "details": "Survived water landing, SpaceX couldn't tug it back to port, so they hired a company to destroy it.  ",
#         "missions": [
#             {
#                 "flight": 39,
#                 "name": "NROL-76"
#             },
#             {
#                 "flight": 54,
#                 "name": "SES-16 / GovSat-1"
#             }
#         ],
#         "original_launch": "2017-05-01T11:15:00.000Z",
#         "original_launch_unix": 1493637300,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1034",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 40,
#                 "name": "Inmarsat-5 F4"
#             }
#         ],
#         "original_launch": "2017-05-15T23:21:00.000Z",
#         "original_launch_unix": 1494890460,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1035",
#         "details": "To be moved to Space Center Houston for display this summer.",
#         "missions": [
#             {
#                 "flight": 41,
#                 "name": "CRS-11"
#             },
#             {
#                 "flight": 51,
#                 "name": "CRS-13"
#             }
#         ],
#         "original_launch": "2017-06-03T21:07:00.000Z",
#         "original_launch_unix": 1496524020,
#         "reuse_count": 1,
#         "rtls_attempts": 2,
#         "rtls_landings": 2,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 3,
#         "core_serial": "B1036",
#         "details": "Broke Up After Successful Water Landing",
#         "missions": [
#             {
#                 "flight": 43,
#                 "name": "Iridium NEXT Mission 2"
#             },
#             {
#                 "flight": 52,
#                 "name": "Iridium NEXT Mission 4"
#             }
#         ],
#         "original_launch": "2017-06-25T13:25:00.000Z",
#         "original_launch_unix": 1498397100,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1037",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 44,
#                 "name": "Intelsat 35e"
#             }
#         ],
#         "original_launch": "2017-07-05T23:35:00.000Z",
#         "original_launch_unix": 1499297700,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 4,
#         "core_serial": "B1039",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 45,
#                 "name": "CRS-12"
#             },
#             {
#                 "flight": 59,
#                 "name": "CRS-14"
#             }
#         ],
#         "original_launch": "2017-08-14T16:31:00.000Z",
#         "original_launch_unix": 1502728260,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 3,
#         "core_serial": "B1038",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 46,
#                 "name": "FormoSat-5"
#             },
#             {
#                 "flight": 56,
#                 "name": "Paz / Starlink Demo"
#             }
#         ],
#         "original_launch": "2017-08-24T18:50:00.000Z",
#         "original_launch_unix": 1503600600,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 4,
#         "core_serial": "B1040",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 47,
#                 "name": "Boeing X-37B OTV-5"
#             },
#             {
#                 "flight": 63,
#                 "name": "SES-12"
#             }
#         ],
#         "original_launch": "2017-09-07T13:50:00.000Z",
#         "original_launch_unix": 1504792200,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 4,
#         "core_serial": "B1041",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 48,
#                 "name": "Iridium NEXT Mission 3"
#             },
#             {
#                 "flight": 58,
#                 "name": "Iridium NEXT Mission 5"
#             }
#         ],
#         "original_launch": "2017-10-09T12:37:00.000Z",
#         "original_launch_unix": 1507552620,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 4,
#         "core_serial": "B1042",
#         "details": "retired. ",
#         "missions": [
#             {
#                 "flight": 50,
#                 "name": "KoreaSat 5A"
#             }
#         ],
#         "original_launch": "2017-10-30T19:34:00.000Z",
#         "original_launch_unix": 1509392040,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "inactive",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 4,
#         "core_serial": "B1043",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 53,
#                 "name": "ZUMA"
#             },
#             {
#                 "flight": 62,
#                 "name": "Iridium NEXT Mission 6"
#             }
#         ],
#         "original_launch": "2017-11-11T23:00:00.000Z",
#         "original_launch_unix": 1510441200,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 3,
#         "core_serial": "B1033",
#         "details": "Two of the outer engines didn't re-ignite for the landing burn, ran out of TEA/TEB igniters. ",
#         "missions": [
#             {
#                 "flight": 55,
#                 "name": "Falcon Heavy Test Flight"
#             }
#         ],
#         "original_launch": "2018-02-06T20:45:00.000Z",
#         "original_launch_unix": 1517949900,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 4,
#         "core_serial": "B1044",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 57,
#                 "name": "Hispasat 30W-6"
#             }
#         ],
#         "original_launch": "2018-03-06T05:33:00.000Z",
#         "original_launch_unix": 1520314380,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 4,
#         "core_serial": "B1045",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 60,
#                 "name": "TESS"
#             },
#             {
#                 "flight": 64,
#                 "name": "CRS-15"
#             }
#         ],
#         "original_launch": "2018-04-18T22:51:00.000Z",
#         "original_launch_unix": 1524091860,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 3,
#         "asds_landings": 3,
#         "block": 5,
#         "core_serial": "B1046",
#         "details": "Undergoing refurbishment.",
#         "missions": [
#             {
#                 "flight": 61,
#                 "name": "Bangabandhu-1"
#             },
#             {
#                 "flight": 67,
#                 "name": "Merah Putih"
#             },
#             {
#                 "flight": 71,
#                 "name": "SSO-A"
#             }
#         ],
#         "original_launch": "2018-05-11T20:14:00.000Z",
#         "original_launch_unix": 1526069640,
#         "reuse_count": 2,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "active",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 2,
#         "asds_landings": 2,
#         "block": 5,
#         "core_serial": "B1047",
#         "details": "Landed on OCISLY as of Nov 15, 2018. ",
#         "missions": [
#             {
#                 "flight": 65,
#                 "name": "Telstar 19V"
#             },
#             {
#                 "flight": 70,
#                 "name": "Es\u2019hail 2"
#             }
#         ],
#         "original_launch": "2018-07-22T05:50:00.000Z",
#         "original_launch_unix": 1532238600,
#         "reuse_count": 1,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 2,
#         "asds_landings": 2,
#         "block": 5,
#         "core_serial": "B1048",
#         "details": "Unloaded at Port Canaveral as of Feb 25, 2019. ",
#         "missions": [
#             {
#                 "flight": 66,
#                 "name": "Iridium NEXT Mission 7"
#             },
#             {
#                 "flight": 69,
#                 "name": "SAOCOM 1A"
#             },
#             {
#                 "flight": 75,
#                 "name": "Nusantara Satu (PSN-6) / S5 / Beresheet"
#             }
#         ],
#         "original_launch": "2018-07-25T11:39:26.000Z",
#         "original_launch_unix": 1532518766,
#         "reuse_count": 2,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 3,
#         "asds_landings": 3,
#         "block": 5,
#         "core_serial": "B1049",
#         "details": "Landed on OCISLY as of May 24, 2019. ",
#         "missions": [
#             {
#                 "flight": 68,
#                 "name": "Telstar 18V"
#             },
#             {
#                 "flight": 74,
#                 "name": "Iridium NEXT Mission 8"
#             },
#             {
#                 "flight": 79,
#                 "name": "Starlink 1 (v0.9)"
#             }
#         ],
#         "original_launch": "2018-09-10T04:45:00.000Z",
#         "original_launch_unix": 1536554700,
#         "reuse_count": 2,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 5,
#         "core_serial": "B1050",
#         "details": "Towed to Port of Canaveral; future utility unknown as of Dec 7, 2018. ",
#         "missions": [
#             {
#                 "flight": 72,
#                 "name": "CRS-16"
#             }
#         ],
#         "original_launch": "2018-12-15T00:00:00.000Z",
#         "original_launch_unix": 1544832000,
#         "reuse_count": 0,
#         "rtls_attempts": 1,
#         "rtls_landings": 0,
#         "status": "unknown",
#         "water_landing": true
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 5,
#         "core_serial": "B1054",
#         "details": "Stage Expended",
#         "missions": [
#             {
#                 "flight": 73,
#                 "name": "GPS III SV01"
#             }
#         ],
#         "original_launch": "2018-12-23T13:51:00.000Z",
#         "original_launch_unix": 1545573060,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 5,
#         "core_serial": "B1051",
#         "details": "Landed at LZ-4 as of Jun 15, 2019. ",
#         "missions": [
#             {
#                 "flight": 76,
#                 "name": "CCtCap Demo Mission 1"
#             },
#             {
#                 "flight": 80,
#                 "name": "RADARSAT Constellation"
#             }
#         ],
#         "original_launch": "2019-03-02T07:45:00.000Z",
#         "original_launch_unix": 1551512700,
#         "reuse_count": 1,
#         "rtls_attempts": 1,
#         "rtls_landings": 1,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 5,
#         "core_serial": "B1052",
#         "details": "Landed at LZ-1 as of Jun 25, 2019. ",
#         "missions": [
#             {
#                 "flight": 77,
#                 "name": "ArabSat 6A"
#             },
#             {
#                 "flight": 81,
#                 "name": "STP-2"
#             }
#         ],
#         "original_launch": "2019-04-11T22:35:00.000Z",
#         "original_launch_unix": 1555022100,
#         "reuse_count": 1,
#         "rtls_attempts": 2,
#         "rtls_landings": 2,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 0,
#         "asds_landings": 0,
#         "block": 5,
#         "core_serial": "B1053",
#         "details": "Landed at LZ-2 as of Jun 25, 2019. ",
#         "missions": [
#             {
#                 "flight": 77,
#                 "name": "ArabSat 6A"
#             },
#             {
#                 "flight": 81,
#                 "name": "STP-2"
#             }
#         ],
#         "original_launch": "2019-04-11T22:35:00.000Z",
#         "original_launch_unix": 1555022100,
#         "reuse_count": 1,
#         "rtls_attempts": 2,
#         "rtls_landings": 2,
#         "status": "unknown",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 5,
#         "core_serial": "B1055",
#         "details": "Toppled by rough seas and broken in two after safely landing aboard OCISLY",
#         "missions": [
#             {
#                 "flight": 77,
#                 "name": "ArabSat 6A"
#             }
#         ],
#         "original_launch": "2019-04-11T22:35:00.000Z",
#         "original_launch_unix": 1555022100,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 1,
#         "block": 5,
#         "core_serial": "B1056",
#         "details": "Undergoing refurbishment at the Cape.",
#         "missions": [
#             {
#                 "flight": 78,
#                 "name": "CRS-17"
#             }
#         ],
#         "original_launch": "2019-05-04T06:48:00.000Z",
#         "original_launch_unix": 1556952480,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "active",
#         "water_landing": false
#     },
#     {
#         "asds_attempts": 1,
#         "asds_landings": 0,
#         "block": 5,
#         "core_serial": "B1057",
#         "details": "Exploded upon ocean impact a safe distance from OCISLY",
#         "missions": [
#             {
#                 "flight": 81,
#                 "name": "STP-2"
#             }
#         ],
#         "original_launch": null,
#         "original_launch_unix": null,
#         "reuse_count": 0,
#         "rtls_attempts": 0,
#         "rtls_landings": 0,
#         "status": "lost",
#         "water_landing": false
#     }
# ]

# %%
url = "https://api.spacexdata.com/v3/launches/1"
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "crew": null,
#     "details": "Engine failure at 33 seconds and loss of vehicle",
#     "flight_number": 1,
#     "is_tentative": false,
#     "launch_date_local": "2006-03-25T10:30:00+12:00",
#     "launch_date_unix": 1143239400,
#     "launch_date_utc": "2006-03-24T22:30:00.000Z",
#     "launch_failure_details": {
#         "altitude": null,
#         "reason": "merlin engine failure",
#         "time": 33
#     },
#     "launch_site": {
#         "site_id": "kwajalein_atoll",
#         "site_name": "Kwajalein Atoll",
#         "site_name_long": "Kwajalein Atoll Omelek Island"
#     },
#     "launch_success": false,
#     "launch_window": 0,
#     "launch_year": "2006",
#     "links": {
#         "article_link": "https://www.space.com/2196-spacex-inaugural-falcon-1-rocket-lost-launch.html",
#         "flickr_images": [],
#         "mission_patch": "https://images2.imgbox.com/40/e3/GypSkayF_o.png",
#         "mission_patch_small": "https://images2.imgbox.com/3c/0e/T8iJcSN3_o.png",
#         "presskit": null,
#         "reddit_campaign": null,
#         "reddit_launch": null,
#         "reddit_media": null,
#         "reddit_recovery": null,
#         "video_link": "https://www.youtube.com/watch?v=0a_00nJ_Y88",
#         "wikipedia": "https://en.wikipedia.org/wiki/DemoSat",
#         "youtube_id": "0a_00nJ_Y88"
#     },
#     "mission_id": [],
#     "mission_name": "FalconSat",
#     "rocket": {
#         "fairings": {
#             "recovered": false,
#             "recovery_attempt": false,
#             "reused": false,
#             "ship": null
#         },
#         "first_stage": {
#             "cores": [
#                 {
#                     "block": null,
#                     "core_serial": "Merlin1A",
#                     "flight": 1,
#                     "gridfins": false,
#                     "land_success": null,
#                     "landing_intent": false,
#                     "landing_type": null,
#                     "landing_vehicle": null,
#                     "legs": false,
#                     "reused": false
#                 }
#             ]
#         },
#         "rocket_id": "falcon1",
#         "rocket_name": "Falcon 1",
#         "rocket_type": "Merlin A",
#         "second_stage": {
#             "block": 1,
#             "payloads": [
#                 {
#                     "customers": [
#                         "DARPA"
#                     ],
#                     "manufacturer": "SSTL",
#                     "nationality": "United States",
#                     "norad_id": [],
#                     "orbit": "LEO",
#                     "orbit_params": {
#                         "apoapsis_km": 500,
#                         "arg_of_pericenter": null,
#                         "eccentricity": null,
#                         "epoch": null,
#                         "inclination_deg": 39,
#                         "lifespan_years": null,
#                         "longitude": null,
#                         "mean_anomaly": null,
#                         "mean_motion": null,
#                         "periapsis_km": 400,
#                         "period_min": null,
#                         "raan": null,
#                         "reference_system": "geocentric",
#                         "regime": "low-earth",
#                         "semi_major_axis_km": null
#                     },
#                     "payload_id": "FalconSAT-2",
#                     "payload_mass_kg": 20,
#                     "payload_mass_lbs": 43,
#                     "payload_type": "Satellite",
#                     "reused": false
#                 }
#             ]
#         }
#     },
#     "ships": [],
#     "static_fire_date_unix": 1142553600,
#     "static_fire_date_utc": "2006-03-17T00:00:00.000Z",
#     "tbd": false,
#     "telemetry": {
#         "flight_club": null
#     },
#     "tentative_max_precision": "hour",
#     "timeline": {
#         "webcast_liftoff": 54
#     },
#     "upcoming": false
# }
