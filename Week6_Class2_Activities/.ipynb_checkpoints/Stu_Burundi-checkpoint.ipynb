# %%
# Dependencies
import requests
from config import api_key
import json

# %%
# Build query URL and request your results in Celsius
url = "http://api.openweathermap.org/data/2.5/weather?" #id=524901&APPID"
city = "Bujumbura"

#url2 = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
#url2 = url2 + api_key
query = url + "q=" + city + "&APPID" + api_key
# Get weather data
response = requests.get(url2).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 90
#             },
#             "dt": 1562295600,
#             "dt_txt": "2019-07-05 03:00:00",
#             "main": {
#                 "grnd_level": 985.76,
#                 "humidity": 81,
#                 "pressure": 1008.23,
#                 "sea_level": 1008.23,
#                 "temp": 284.33,
#                 "temp_kf": 1.33,
#                 "temp_max": 284.33,
#                 "temp_min": 283
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 263.474,
#                 "speed": 4.16
#             }
#         },
#         {
#             "clouds": {
#                 "all": 47
#             },
#             "dt": 1562306400,
#             "dt_txt": "2019-07-05 06:00:00",
#             "main": {
#                 "grnd_level": 985.85,
#                 "humidity": 58,
#                 "pressure": 1008.12,
#                 "sea_level": 1008.12,
#                 "temp": 289.29,
#                 "temp_kf": 1,
#                 "temp_max": 289.29,
#                 "temp_min": 288.291
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 260.572,
#                 "speed": 4.17
#             }
#         },
#         {
#             "clouds": {
#                 "all": 34
#             },
#             "dt": 1562317200,
#             "dt_txt": "2019-07-05 09:00:00",
#             "main": {
#                 "grnd_level": 984.58,
#                 "humidity": 49,
#                 "pressure": 1006.69,
#                 "sea_level": 1006.69,
#                 "temp": 291.61,
#                 "temp_kf": 0.67,
#                 "temp_max": 291.61,
#                 "temp_min": 290.94
#             },
#             "rain": {
#                 "3h": 0.062
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 249.37,
#                 "speed": 5.38
#             }
#         },
#         {
#             "clouds": {
#                 "all": 57
#             },
#             "dt": 1562328000,
#             "dt_txt": "2019-07-05 12:00:00",
#             "main": {
#                 "grnd_level": 983.91,
#                 "humidity": 47,
#                 "pressure": 1006.1,
#                 "sea_level": 1006.1,
#                 "temp": 291.95,
#                 "temp_kf": 0.33,
#                 "temp_max": 291.95,
#                 "temp_min": 291.619
#             },
#             "rain": {
#                 "3h": 0.063
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 243.572,
#                 "speed": 5.79
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1562338800,
#             "dt_txt": "2019-07-05 15:00:00",
#             "main": {
#                 "grnd_level": 982.64,
#                 "humidity": 68,
#                 "pressure": 1004.65,
#                 "sea_level": 1004.65,
#                 "temp": 288.8,
#                 "temp_kf": 0,
#                 "temp_max": 288.8,
#                 "temp_min": 288.8
#             },
#             "rain": {
#                 "3h": 0.188
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 248.628,
#                 "speed": 3.96
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1562349600,
#             "dt_txt": "2019-07-05 18:00:00",
#             "main": {
#                 "grnd_level": 981.54,
#                 "humidity": 72,
#                 "pressure": 1003.63,
#                 "sea_level": 1003.63,
#                 "temp": 287.612,
#                 "temp_kf": 0,
#                 "temp_max": 287.612,
#                 "temp_min": 287.612
#             },
#             "rain": {
#                 "3h": 0.124
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 221.627,
#                 "speed": 3.43
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1562360400,
#             "dt_txt": "2019-07-05 21:00:00",
#             "main": {
#                 "grnd_level": 979.94,
#                 "humidity": 81,
#                 "pressure": 1001.88,
#                 "sea_level": 1001.88,
#                 "temp": 286.412,
#                 "temp_kf": 0,
#                 "temp_max": 286.412,
#                 "temp_min": 286.412
#             },
#             "rain": {
#                 "3h": 0.125
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 218.19,
#                 "speed": 4.82
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1562371200,
#             "dt_txt": "2019-07-06 00:00:00",
#             "main": {
#                 "grnd_level": 978.45,
#                 "humidity": 90,
#                 "pressure": 1000.94,
#                 "sea_level": 1000.94,
#                 "temp": 285.361,
#                 "temp_kf": 0,
#                 "temp_max": 285.361,
#                 "temp_min": 285.361
#             },
#             "rain": {
#                 "3h": 1.375
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 215.642,
#                 "speed": 4.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1562382000,
#             "dt_txt": "2019-07-06 03:00:00",
#             "main": {
#                 "grnd_level": 977.33,
#                 "humidity": 90,
#                 "pressure": 999.51,
#                 "sea_level": 999.51,
#                 "temp": 283.924,
#                 "temp_kf": 0,
#                 "temp_max": 283.924,
#                 "temp_min": 283.924
#             },
#             "rain": {
#                 "3h": 3.625
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10d",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 258.48,
#                 "speed": 2.94
#             }
#         },
#         {
#             "clouds": {
#                 "all": 67
#             },
#             "dt": 1562392800,
#             "dt_txt": "2019-07-06 06:00:00",
#             "main": {
#                 "grnd_level": 976.98,
#                 "humidity": 70,
#                 "pressure": 999.15,
#                 "sea_level": 999.15,
#                 "temp": 286.724,
#                 "temp_kf": 0,
#                 "temp_max": 286.724,
#                 "temp_min": 286.724
#             },
#             "rain": {
#                 "3h": 0.063
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 251.789,
#                 "speed": 4.93
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1562403600,
#             "dt_txt": "2019-07-06 09:00:00",
#             "main": {
#                 "grnd_level": 976.27,
#                 "humidity": 51,
#                 "pressure": 998.62,
#                 "sea_level": 998.62,
#                 "temp": 289.56,
#                 "temp_kf": 0,
#                 "temp_max": 289.56,
#                 "temp_min": 289.56
#             },
#             "rain": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 237.858,
#                 "speed": 5.96
#             }
#         },
#         {
#             "clouds": {
#                 "all": 46
#             },
#             "dt": 1562414400,
#             "dt_txt": "2019-07-06 12:00:00",
#             "main": {
#                 "grnd_level": 976.03,
#                 "humidity": 73,
#                 "pressure": 997.56,
#                 "sea_level": 997.56,
#                 "temp": 286.321,
#                 "temp_kf": 0,
#                 "temp_max": 286.321,
#                 "temp_min": 286.321
#             },
#             "rain": {
#                 "3h": 1.562
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 241.308,
#                 "speed": 5.62
#             }
#         },
#         {
#             "clouds": {
#                 "all": 59
#             },
#             "dt": 1562425200,
#             "dt_txt": "2019-07-06 15:00:00",
#             "main": {
#                 "grnd_level": 974.19,
#                 "humidity": 73,
#                 "pressure": 996.52,
#                 "sea_level": 996.52,
#                 "temp": 286.561,
#                 "temp_kf": 0,
#                 "temp_max": 286.561,
#                 "temp_min": 286.561
#             },
#             "rain": {
#                 "3h": 1.125
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 229.54,
#                 "speed": 7.09
#             }
#         },
#         {
#             "clouds": {
#                 "all": 79
#             },
#             "dt": 1562436000,
#             "dt_txt": "2019-07-06 18:00:00",
#             "main": {
#                 "grnd_level": 973.85,
#                 "humidity": 88,
#                 "pressure": 996.91,
#                 "sea_level": 996.91,
#                 "temp": 283.743,
#                 "temp_kf": 0,
#                 "temp_max": 283.743,
#                 "temp_min": 283.743
#             },
#             "rain": {
#                 "3h": 2.937
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 262.012,
#                 "speed": 5.8
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1562446800,
#             "dt_txt": "2019-07-06 21:00:00",
#             "main": {
#                 "grnd_level": 975.73,
#                 "humidity": 90,
#                 "pressure": 997.62,
#                 "sea_level": 997.62,
#                 "temp": 282.343,
#                 "temp_kf": 0,
#                 "temp_max": 282.343,
#                 "temp_min": 282.343
#             },
#             "rain": {
#                 "3h": 0.438
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 260.418,
#                 "speed": 4.33
#             }
#         },
#         {
#             "clouds": {
#                 "all": 63
#             },
#             "dt": 1562457600,
#             "dt_txt": "2019-07-07 00:00:00",
#             "main": {
#                 "grnd_level": 976.37,
#                 "humidity": 94,
#                 "pressure": 998.4,
#                 "sea_level": 998.4,
#                 "temp": 282,
#                 "temp_kf": 0,
#                 "temp_max": 282,
#                 "temp_min": 282
#             },
#             "rain": {},
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 255.798,
#                 "speed": 4.45
#             }
#         },
#         {
#             "clouds": {
#                 "all": 96
#             },
#             "dt": 1562468400,
#             "dt_txt": "2019-07-07 03:00:00",
#             "main": {
#                 "grnd_level": 977.21,
#                 "humidity": 91,
#                 "pressure": 999.33,
#                 "sea_level": 999.33,
#                 "temp": 283.204,
#                 "temp_kf": 0,
#                 "temp_max": 283.204,
#                 "temp_min": 283.204
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 261.572,
#                 "speed": 4.6
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1562479200,
#             "dt_txt": "2019-07-07 06:00:00",
#             "main": {
#                 "grnd_level": 978.21,
#                 "humidity": 85,
#                 "pressure": 1000.27,
#                 "sea_level": 1000.27,
#                 "temp": 284.7,
#                 "temp_kf": 0,
#                 "temp_max": 284.7,
#                 "temp_min": 284.7
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 258.513,
#                 "speed": 4.07
#             }
#         },
#         {
#             "clouds": {
#                 "all": 91
#             },
#             "dt": 1562490000,
#             "dt_txt": "2019-07-07 09:00:00",
#             "main": {
#                 "grnd_level": 978.57,
#                 "humidity": 66,
#                 "pressure": 1000.52,
#                 "sea_level": 1000.52,
#                 "temp": 288.759,
#                 "temp_kf": 0,
#                 "temp_max": 288.759,
#                 "temp_min": 288.759
#             },
#             "rain": {
#                 "3h": 0.125
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 259.82,
#                 "speed": 3.9
#             }
#         },
#         {
#             "clouds": {
#                 "all": 51
#             },
#             "dt": 1562500800,
#             "dt_txt": "2019-07-07 12:00:00",
#             "main": {
#                 "grnd_level": 977.81,
#                 "humidity": 52,
#                 "pressure": 1000.02,
#                 "sea_level": 1000.02,
#                 "temp": 292.232,
#                 "temp_kf": 0,
#                 "temp_max": 292.232,
#                 "temp_min": 292.232
#             },
#             "rain": {
#                 "3h": 0.313
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 253.293,
#                 "speed": 4.37
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1562511600,
#             "dt_txt": "2019-07-07 15:00:00",
#             "main": {
#                 "grnd_level": 977.54,
#                 "humidity": 63,
#                 "pressure": 999.68,
#                 "sea_level": 999.68,
#                 "temp": 291.1,
#                 "temp_kf": 0,
#                 "temp_max": 291.1,
#                 "temp_min": 291.1
#             },
#             "rain": {
#                 "3h": 1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 240.77,
#                 "speed": 4.13
#             }
#         },
#         {
#             "clouds": {
#                 "all": 33
#             },
#             "dt": 1562522400,
#             "dt_txt": "2019-07-07 18:00:00",
#             "main": {
#                 "grnd_level": 977.67,
#                 "humidity": 82,
#                 "pressure": 999.55,
#                 "sea_level": 999.55,
#                 "temp": 287.449,
#                 "temp_kf": 0,
#                 "temp_max": 287.449,
#                 "temp_min": 287.449
#             },
#             "rain": {
#                 "3h": 0.438
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 226.853,
#                 "speed": 4.09
#             }
#         },
#         {
#             "clouds": {
#                 "all": 28
#             },
#             "dt": 1562533200,
#             "dt_txt": "2019-07-07 21:00:00",
#             "main": {
#                 "grnd_level": 977.32,
#                 "humidity": 90,
#                 "pressure": 999.31,
#                 "sea_level": 999.31,
#                 "temp": 284.651,
#                 "temp_kf": 0,
#                 "temp_max": 284.651,
#                 "temp_min": 284.651
#             },
#             "rain": {
#                 "3h": 0.125
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 228.838,
#                 "speed": 2.48
#             }
#         },
#         {
#             "clouds": {
#                 "all": 14
#             },
#             "dt": 1562544000,
#             "dt_txt": "2019-07-08 00:00:00",
#             "main": {
#                 "grnd_level": 976.85,
#                 "humidity": 92,
#                 "pressure": 998.87,
#                 "sea_level": 998.87,
#                 "temp": 284.098,
#                 "temp_kf": 0,
#                 "temp_max": 284.098,
#                 "temp_min": 284.098
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 215.261,
#                 "speed": 1.92
#             }
#         },
#         {
#             "clouds": {
#                 "all": 11
#             },
#             "dt": 1562554800,
#             "dt_txt": "2019-07-08 03:00:00",
#             "main": {
#                 "grnd_level": 976.73,
#                 "humidity": 91,
#                 "pressure": 998.76,
#                 "sea_level": 998.76,
#                 "temp": 285.398,
#                 "temp_kf": 0,
#                 "temp_max": 285.398,
#                 "temp_min": 285.398
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 216.928,
#                 "speed": 2.57
#             }
#         },
#         {
#             "clouds": {
#                 "all": 16
#             },
#             "dt": 1562565600,
#             "dt_txt": "2019-07-08 06:00:00",
#             "main": {
#                 "grnd_level": 976.17,
#                 "humidity": 76,
#                 "pressure": 998.07,
#                 "sea_level": 998.07,
#                 "temp": 289.5,
#                 "temp_kf": 0,
#                 "temp_max": 289.5,
#                 "temp_min": 289.5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 225.945,
#                 "speed": 3.82
#             }
#         },
#         {
#             "clouds": {
#                 "all": 27
#             },
#             "dt": 1562576400,
#             "dt_txt": "2019-07-08 09:00:00",
#             "main": {
#                 "grnd_level": 976.18,
#                 "humidity": 53,
#                 "pressure": 998.27,
#                 "sea_level": 998.27,
#                 "temp": 292.806,
#                 "temp_kf": 0,
#                 "temp_max": 292.806,
#                 "temp_min": 292.806
#             },
#             "rain": {
#                 "3h": 0.75
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 237.842,
#                 "speed": 5.25
#             }
#         },
#         {
#             "clouds": {
#                 "all": 13
#             },
#             "dt": 1562587200,
#             "dt_txt": "2019-07-08 12:00:00",
#             "main": {
#                 "grnd_level": 975.99,
#                 "humidity": 50,
#                 "pressure": 998.05,
#                 "sea_level": 998.05,
#                 "temp": 293,
#                 "temp_kf": 0,
#                 "temp_max": 293,
#                 "temp_min": 293
#             },
#             "rain": {
#                 "3h": 0.938
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 259.529,
#                 "speed": 5.96
#             }
#         },
#         {
#             "clouds": {
#                 "all": 11
#             },
#             "dt": 1562598000,
#             "dt_txt": "2019-07-08 15:00:00",
#             "main": {
#                 "grnd_level": 977.08,
#                 "humidity": 61,
#                 "pressure": 998.87,
#                 "sea_level": 998.87,
#                 "temp": 290.7,
#                 "temp_kf": 0,
#                 "temp_max": 290.7,
#                 "temp_min": 290.7
#             },
#             "rain": {
#                 "3h": 0.5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 255.572,
#                 "speed": 5.61
#             }
#         },
#         {
#             "clouds": {
#                 "all": 18
#             },
#             "dt": 1562608800,
#             "dt_txt": "2019-07-08 18:00:00",
#             "main": {
#                 "grnd_level": 976.93,
#                 "humidity": 79,
#                 "pressure": 998.9,
#                 "sea_level": 998.9,
#                 "temp": 286.849,
#                 "temp_kf": 0,
#                 "temp_max": 286.849,
#                 "temp_min": 286.849
#             },
#             "rain": {
#                 "3h": 0.125
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 254.767,
#                 "speed": 3.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 60
#             },
#             "dt": 1562619600,
#             "dt_txt": "2019-07-08 21:00:00",
#             "main": {
#                 "grnd_level": 977.81,
#                 "humidity": 89,
#                 "pressure": 1000.01,
#                 "sea_level": 1000.01,
#                 "temp": 285.038,
#                 "temp_kf": 0,
#                 "temp_max": 285.038,
#                 "temp_min": 285.038
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 241.394,
#                 "speed": 4.16
#             }
#         },
#         {
#             "clouds": {
#                 "all": 50
#             },
#             "dt": 1562630400,
#             "dt_txt": "2019-07-09 00:00:00",
#             "main": {
#                 "grnd_level": 977.46,
#                 "humidity": 93,
#                 "pressure": 999.83,
#                 "sea_level": 999.83,
#                 "temp": 283.989,
#                 "temp_kf": 0,
#                 "temp_max": 283.989,
#                 "temp_min": 283.989
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 240.703,
#                 "speed": 4.29
#             }
#         },
#         {
#             "clouds": {
#                 "all": 28
#             },
#             "dt": 1562641200,
#             "dt_txt": "2019-07-09 03:00:00",
#             "main": {
#                 "grnd_level": 977.84,
#                 "humidity": 89,
#                 "pressure": 1000.15,
#                 "sea_level": 1000.15,
#                 "temp": 284.455,
#                 "temp_kf": 0,
#                 "temp_max": 284.455,
#                 "temp_min": 284.455
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 245.198,
#                 "speed": 3.98
#             }
#         },
#         {
#             "clouds": {
#                 "all": 47
#             },
#             "dt": 1562652000,
#             "dt_txt": "2019-07-09 06:00:00",
#             "main": {
#                 "grnd_level": 978.31,
#                 "humidity": 76,
#                 "pressure": 1000.33,
#                 "sea_level": 1000.33,
#                 "temp": 287.768,
#                 "temp_kf": 0,
#                 "temp_max": 287.768,
#                 "temp_min": 287.768
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 239.134,
#                 "speed": 4.72
#             }
#         },
#         {
#             "clouds": {
#                 "all": 70
#             },
#             "dt": 1562662800,
#             "dt_txt": "2019-07-09 09:00:00",
#             "main": {
#                 "grnd_level": 978.81,
#                 "humidity": 66,
#                 "pressure": 1000.69,
#                 "sea_level": 1000.69,
#                 "temp": 290.217,
#                 "temp_kf": 0,
#                 "temp_max": 290.217,
#                 "temp_min": 290.217
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 250.984,
#                 "speed": 5.56
#             }
#         },
#         {
#             "clouds": {
#                 "all": 82
#             },
#             "dt": 1562673600,
#             "dt_txt": "2019-07-09 12:00:00",
#             "main": {
#                 "grnd_level": 978.66,
#                 "humidity": 63,
#                 "pressure": 1000.34,
#                 "sea_level": 1000.34,
#                 "temp": 290.085,
#                 "temp_kf": 0,
#                 "temp_max": 290.085,
#                 "temp_min": 290.085
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 242.297,
#                 "speed": 4.6
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1562684400,
#             "dt_txt": "2019-07-09 15:00:00",
#             "main": {
#                 "grnd_level": 978.4,
#                 "humidity": 65,
#                 "pressure": 1000.2,
#                 "sea_level": 1000.2,
#                 "temp": 290.688,
#                 "temp_kf": 0,
#                 "temp_max": 290.688,
#                 "temp_min": 290.688
#             },
#             "rain": {
#                 "3h": 0.062
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 249.903,
#                 "speed": 4.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 92
#             },
#             "dt": 1562695200,
#             "dt_txt": "2019-07-09 18:00:00",
#             "main": {
#                 "grnd_level": 978.03,
#                 "humidity": 81,
#                 "pressure": 999.84,
#                 "sea_level": 999.84,
#                 "temp": 287.134,
#                 "temp_kf": 0,
#                 "temp_max": 287.134,
#                 "temp_min": 287.134
#             },
#             "rain": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 238.578,
#                 "speed": 2.92
#             }
#         },
#         {
#             "clouds": {
#                 "all": 62
#             },
#             "dt": 1562706000,
#             "dt_txt": "2019-07-09 21:00:00",
#             "main": {
#                 "grnd_level": 977.77,
#                 "humidity": 90,
#                 "pressure": 999.64,
#                 "sea_level": 999.64,
#                 "temp": 284.923,
#                 "temp_kf": 0,
#                 "temp_max": 284.923,
#                 "temp_min": 284.923
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 238.481,
#                 "speed": 2.76
#             }
#         },
#         {
#             "clouds": {
#                 "all": 32
#             },
#             "dt": 1562716800,
#             "dt_txt": "2019-07-10 00:00:00",
#             "main": {
#                 "grnd_level": 977.24,
#                 "humidity": 93,
#                 "pressure": 999.39,
#                 "sea_level": 999.39,
#                 "temp": 283.514,
#                 "temp_kf": 0,
#                 "temp_max": 283.514,
#                 "temp_min": 283.514
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 244.878,
#                 "speed": 2.41
#             }
#         }
#     ],
#     "message": 0.0072
# }

# %%
# Get temperature from JSON response
print(response)
# Out:
# <Response [200]>

# %%
# Report temperature
