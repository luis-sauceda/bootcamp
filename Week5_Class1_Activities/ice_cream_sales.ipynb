# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]
scoop_price =[values/random.random() for values in temp]
scoop_price
# Out:
# [28.812636654491083,
#  17.253412980003755,
#  76.28958438097578,
#  17.63795692685449,
#  31.317498705836698,
#  49.79118557921275,
#  32.79422037722137,
#  29.332444601561807,
#  30.35078273432336,
#  48.16364215492155,
#  56.337216599897516,
#  31.793368549388497]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp, sales, marker="o", facecolors="red", edgecolors="black", s=scoop_price, alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Set the upper and lower limits of our y axis
plt.ylim(min(sales)-10, max(sales)+10)
# Out:
# (175, 624)

# %%
# Set the upper and lower limits of our x axis
plt.xlim(min(temp)-1,max(temp)+1)
# Out:
# (10.9, 26.1)

# %%
# Create a title, x label, and y label for our chart
plt.title("Relation between temperature and ice-cream sales")
plt.xlabel("Temperature (c°)")
plt.ylabel("Sales (K USD)")
# Out:
# Text(45.79166975286272, 0.5, 'Sales (K USD)')

# %%
# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.savefig("pyIceCream.png")
plt.show()
