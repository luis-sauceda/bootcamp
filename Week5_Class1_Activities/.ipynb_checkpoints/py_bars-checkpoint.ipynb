# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(cities, bars_in_cities, color="r", alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"])
# Out:
# ([<matplotlib.axis.XTick at 0x1f696920e10>,
#   <matplotlib.axis.XTick at 0x1f6969207f0>,
#   <matplotlib.axis.XTick at 0x1f69693df60>,
#   <matplotlib.axis.XTick at 0x1f696947e80>,
#   <matplotlib.axis.XTick at 0x1f6969524a8>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)- 0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+1)
# Out:
# (0, 9.6)

# %%
# Give the chart a title, x label, and y label
plt.title("Number of bars per city")
plt.xlabel("Cities")
plt.ylabel("Number of bars")
# Out:
# Text(67.04166975286272, 0.5, 'Number of bars')

# %%
# Save an image of the chart and print it to the screen
plt.show()
